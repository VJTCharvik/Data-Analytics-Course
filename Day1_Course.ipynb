# %% [markdown]
# <a href="https://colab.research.google.com/github/VJTCharvik/Data-Analytics-Course/blob/main/Day1_Course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello All')
# Out:
# Hello All

# %%
print('Hello VEERA')
# Out:
# Hello VEERA

# %%
print('Hello \nPython \nHow is your day going?')
# Out:
# Hello
# Python
# How is your day going?

# %%
print("Hello all, I hope your's day is good")
# Out:
# Hello all, I hope your's day is good
